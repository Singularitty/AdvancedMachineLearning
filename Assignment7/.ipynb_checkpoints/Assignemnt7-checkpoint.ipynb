# %% [markdown]
# ## Problem 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### i) Clean, No noise

# %%
periods = 100
points_per_period = 50
lag = 12
data = np.sin(np.linspace(0, 2*np.pi*periods, num=periods*points_per_period))

x, y = [], []
for i in range(lag, data.shape[0]-1):
  x.append(data[i-lag:i])
  y.append(data[i])

y = np.array(y)
x_lstm = np.expand_dims(x, axis=2)

# %%
plt.plot(data[:100])

# %%
lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer((lag,1)),
    tf.keras.layers.LSTM(10, return_sequences=False),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

lstm_model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit first 2400 samples

# %%
lstm_model.fit(x=x_lstm[:2400], 
               y=y[:2400], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2400/2400 [==============================] - 17s 4ms/step - loss: 0.0514

# %%
predictions = lstm_model(x_lstm[2400:2500])
print("Mean Squared Error:", mean_squared_error(y[2400:2500], predictions))
# Out:
# Mean Squared Error: 0.0040964516975759814

# %% [markdown]
# Fit the rest of the points

# %%
lstm_model.fit(x=x_lstm[2400:4900], 
               y=y[2400:4900], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.0046

# %%
predictions = lstm_model(x_lstm[4900:5000])
print("Mean Squared Error:", mean_squared_error(y[4900:5000], predictions))
# Out:
# Mean Squared Error: 0.004839677237637942

# %% [markdown]
# ### ii) With noise

# %%
periods = 100
points_per_period = 50
lag = 12
data = np.sin(np.linspace(0, 2*np.pi*periods, num=periods*points_per_period))
noise = np.random.normal(0, 0.05, len(data))
data_noisy = data + noise

x, y = [], []
for i in range(lag, data_noisy.shape[0]-1):
  x.append(data_noisy[i-lag:i])
  y.append(data_noisy[i])

y_noisy = np.array(y)
x_noisy = np.expand_dims(x, axis=2)

# %%
plt.plot(data_noisy[:100])

# %%
lstm_model_ii = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer((lag,1)),
    tf.keras.layers.LSTM(10, return_sequences=False),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

lstm_model_ii.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit first 2400 samples

# %%
lstm_model_ii.fit(x=x_noisy[:2400], 
               y=y_noisy[:2400], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2400/2400 [==============================] - 14s 5ms/step - loss: 0.0285

# %%
predictions = lstm_model_ii(x_noisy[2400:2500])
print("Mean Squared Error:", mean_squared_error(y_noisy[2400:2500], predictions))
# Out:
# Mean Squared Error: 0.007368180144701007

# %% [markdown]
# Fit the rest of the points

# %%
lstm_model_ii.fit(x=x_noisy[2400:4900], 
               y=y_noisy[2400:4900], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2500/2500 [==============================] - 11s 4ms/step - loss: 0.0079

# %%
predictions = lstm_model_ii(x_noisy[4900:5000])
print("Mean Squared Error:", mean_squared_error(y_noisy[4900:5000], predictions))
# Out:
# Mean Squared Error: 0.0052450060712567565

# %% [markdown]
# ## Focused time-lagged feedforward network

# %% [markdown]
# #### i) No Noise

# %% [markdown]
# #### ii) With Noise

# %%
model_ii = tf.keras.models.Sequential([
    tf.keras.layers.Dense(lag, activation='relu', input_dim=x_lstm.shape[1]),
    tf.keras.layers.Dense(1),
])
model_ii.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit first 2400 samples

# %%
model_ii.fit(x=x_noisy[:2400], 
               y=y_noisy[:2400], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2400/2400 [==============================] - 9s 3ms/step - loss: 0.0325

# %%
predictions = model_ii(x_noisy[2400:2500])
print("Mean Squared Error:", mean_squared_error(y_noisy[2400:2500], predictions))
# Out:
# Mean Squared Error: 0.00523345154204174

# %% [markdown]
# Fit the rest of the points

# %%
model_ii.fit(x=x_noisy[2400:4900], 
               y=y_noisy[2400:4900], 
               batch_size=1, 
               epochs=1,
               shuffle=False)
# Out:
# 2500/2500 [==============================] - 7s 3ms/step - loss: 0.0057

# %%
predictions = model_ii(x_noisy[4900:5000])
print("Mean Squared Error:", mean_squared_error(y_noisy[4900:5000], predictions))
# Out:
# Mean Squared Error: 0.009226320704070616

# %% [markdown]
# ## Problem 2

# %%
def autoregression_model(serie):
  t = len(serie)
  return 0.6*serie[t-1] - 0.54*serie[t-2] - 0.44*serie[t-3] + np.random.normal(0, 0.01)

# %%
periods = 100
points_per_period = 50
lag = 12
data = [5,6,3]
for x in range(5000-3):
  data.append(autoregression_model(data))

x, y = [], []
for i in range(lag, len(data)-1):
  x.append(data[i-lag:i])
  y.append(data[i])

y_auto = np.array(y)
x_auto = np.expand_dims(x, axis=2)

# %%
plt.plot(data)

# %% [markdown]
# ### LSTM Model

# %%
lstm_model_2 = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer((lag,1)),
    tf.keras.layers.LSTM(10, return_sequences=False),
    tf.keras.layers.Dense(units=1, activation='tanh')
])

lstm_model_2.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit first 2400 samples

# %%
lstm_model_2.fit(x=x_auto[:2400], 
               y=y_auto[:2400], 
               batch_size=1, 
               epochs=50,
               shuffle=False)
# Out:
# Epoch 1/50
# 2400/2400 [==============================] - 11s 4ms/step - loss: 3.7299
# Epoch 2/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.8314
# Epoch 3/50
# 2400/2400 [==============================] - 8s 3ms/step - loss: 2.7987
# Epoch 4/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7906
# Epoch 5/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7863
# Epoch 6/50
# 2400/2400 [==============================] - 12s 5ms/step - loss: 2.7835
# Epoch 7/50
# 2400/2400 [==============================] - 11s 4ms/step - loss: 2.7817
# Epoch 8/50
# 2400/2400 [==============================] - 8s 3ms/step - loss: 2.7808
# Epoch 9/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7805
# Epoch 10/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7813
# Epoch 11/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7800
# Epoch 12/50
# 2400/2400 [==============================] - 8s 3ms/step - loss: 2.7806
# Epoch 13/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7792
# Epoch 14/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7790
# Epoch 15/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7787
# Epoch 16/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7786
# Epoch 17/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7785
# Epoch 18/50
# 2400/2400 [==============================] - 11s 5ms/step - loss: 2.7783
# Epoch 19/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7782
# Epoch 20/50
# 2400/2400 [==============================] - 13s 5ms/step - loss: 2.7780
# Epoch 21/50
# 2400/2400 [==============================] - 12s 5ms/step - loss: 2.7778
# Epoch 22/50
# 2400/2400 [==============================] - 14s 6ms/step - loss: 2.7777
# Epoch 23/50
# 2400/2400 [==============================] - 13s 5ms/step - loss: 2.7776
# Epoch 24/50
# 2400/2400 [==============================] - 11s 5ms/step - loss: 2.7775
# Epoch 25/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7774
# Epoch 26/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7774
# Epoch 27/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7774
# Epoch 28/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7773
# Epoch 29/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7773
# Epoch 30/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7772
# Epoch 31/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7772
# Epoch 32/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7771
# Epoch 33/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7770
# Epoch 34/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7769
# Epoch 35/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7768
# Epoch 36/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7768
# Epoch 37/50
# 2400/2400 [==============================] - 8s 3ms/step - loss: 2.7767
# Epoch 38/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7766
# Epoch 39/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7767
# Epoch 40/50
# 2400/2400 [==============================] - 8s 4ms/step - loss: 2.7766
# Epoch 41/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7765
# Epoch 42/50
# 2400/2400 [==============================] - 10s 4ms/step - loss: 2.7765
# Epoch 43/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7764
# Epoch 44/50
# 2400/2400 [==============================] - 8s 3ms/step - loss: 2.7764
# Epoch 45/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7764
# Epoch 46/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7763
# Epoch 47/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7763
# Epoch 48/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7762
# Epoch 49/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7762
# Epoch 50/50
# 2400/2400 [==============================] - 9s 4ms/step - loss: 2.7762

# %%
predictions = lstm_model_2(x_auto[2400:2500])
print("Mean Squared Error:", mean_squared_error(y_auto[2400:2500], predictions))
# Out:
# Mean Squared Error: 0.020695592991767656

# %% [markdown]
# Fit the rest of the points

# %%
lstm_model_2.fit(x=x_auto[2400:4900], 
               y=y_auto[2400:4900], 
               batch_size=1, 
               epochs=50,
               shuffle=False)
# Out:
# Epoch 1/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0151
# Epoch 2/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0129
# Epoch 3/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 0.0050
# Epoch 4/50
# 2500/2500 [==============================] - 10s 4ms/step - loss: 0.0021
# Epoch 5/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 8.4347e-04
# Epoch 6/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 5.5021e-04
# Epoch 7/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.6399e-04
# Epoch 8/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 4.3309e-04
# Epoch 9/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 3.2694e-04
# Epoch 10/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 3.0042e-04
# Epoch 11/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.9047e-04
# Epoch 12/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.8576e-04
# Epoch 13/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.8420e-04
# Epoch 14/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.7950e-04
# Epoch 15/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.7570e-04
# Epoch 16/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.7302e-04
# Epoch 17/50
# 2500/2500 [==============================] - 8s 3ms/step - loss: 2.7231e-04
# Epoch 18/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.7542e-04
# Epoch 19/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.8287e-04
# Epoch 20/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.7965e-04
# Epoch 21/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.7412e-04
# Epoch 22/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6870e-04
# Epoch 23/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6520e-04
# Epoch 24/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6679e-04
# Epoch 25/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6419e-04
# Epoch 26/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6393e-04
# Epoch 27/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6293e-04
# Epoch 28/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.5580e-04
# Epoch 29/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5974e-04
# Epoch 30/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6372e-04
# Epoch 31/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6563e-04
# Epoch 32/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.6633e-04
# Epoch 33/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6689e-04
# Epoch 34/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6622e-04
# Epoch 35/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6475e-04
# Epoch 36/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6327e-04
# Epoch 37/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6258e-04
# Epoch 38/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6218e-04
# Epoch 39/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6087e-04
# Epoch 40/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6184e-04
# Epoch 41/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.6256e-04
# Epoch 42/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5868e-04
# Epoch 43/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.5858e-04
# Epoch 44/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5820e-04
# Epoch 45/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5848e-04
# Epoch 46/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5682e-04
# Epoch 47/50
# 2500/2500 [==============================] - 9s 3ms/step - loss: 2.5268e-04
# Epoch 48/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5022e-04
# Epoch 49/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.5437e-04
# Epoch 50/50
# 2500/2500 [==============================] - 9s 4ms/step - loss: 2.4850e-04

# %%
predictions = lstm_model_ii(x_noisy[4900:5000])
print("Mean Squared Error:", mean_squared_error(y_noisy[4900:5000], predictions))

# %% [markdown]
# ### Focused time-lagged feedforward network

# %%
model_2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(lag, activation='relu', input_dim=x_lstm.shape[1]),
    tf.keras.layers.Dense(1),
])

model_2.compile(loss="mean_squared_error", optimizer='adam')

# %% [markdown]
# Fit first 2400 samples

# %%
model_2.fit(x=x_auto[:2400], 
               y=y_auto[:2400], 
               batch_size=1, 
               epochs=50,
               shuffle=False)
# Out:
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.0206

# %%
predictions = model_2(x_auto[2400:2500])
print("Mean Squared Error:", mean_squared_error(y_auto[2400:2500], predictions))
# Out:
# Mean Squared Error: 0.00027845586485210084

# %% [markdown]
# Fit the rest of the points

# %%
model_2.fit(x=x_auto[2400:4900], 
               y=y_auto[2400:4900], 
               batch_size=1, 
               epochs=50,
               shuffle=False)
# Out:
# 2500/2500 [==============================] - 6s 2ms/step - loss: 0.0043

# %%
predictions = model_2(x_auto[4900:5000])
print("Mean Squared Error:", mean_squared_error(y_auto[4900:5000], predictions))
# Out:
# Mean Squared Error: 0.00037115772899994683
